# %% [markdown]
# ![Screenshot 2024-11-04 at 13.11.34.png](attachment:fdcda385-caa1-4126-9f0c-3a9df21b3f45.png)

# %%
Пример

# %%
Ввод

# %%
8
вк
рефераты
вк
ок
одноклассники
яндекс
вконтакте
ок

# %%
Вывод

# %%
6

# %%
Примечания

# %%
Этот пример лишь иллюстрирует формат входных данных. Он намеренно нарушает обещание, что ответ не меньше, чем 
50000.
